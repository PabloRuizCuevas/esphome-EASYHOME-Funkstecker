# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
a=[6996,1036,468,1028,476,524,980,524,976,1020,476,528,972,528,976,1020,480,524,976,1020,480,520,976,528,976,1020,484,520,980,1016,484,1016,492,1008,496,504,992,512,984,1012,492,512,988,512,988,1012,488,512,988]
b=[7016,1016,484,1016,480,520,980,524,980,1016,488,516,980,520,984,1016,484,520,980,1016,484,516,984,520,984,1016,492,508,984,1016,484,1016,488,1012,492,508,992,512,988,1008,492,512,992,508,992,1008,488,512,996]
c=[19532,840,564,832,568,828,1272,824,1276,824,576,820,1284,816,1284,812,1288,812,1288,812,588,808,596,804,596,800,600,796,604,796,608,792,604,792,612,788,1312,788,612,784,1316,788,1312,788,1312,788,612,784,1316]
a=np.array(a)
b=np.array(b)
c=np.array(c)

# %%
np.size(a[1:])/4
# Out:
# 12.0

# %%
x = np.repeat(np.cumsum(np.append(0,a)),2)
x2= np.repeat(np.cumsum(np.append(0,b)),2)
x3= np.repeat(np.cumsum(np.append(0,c)),2)
y = np.tile([1,0,0,1],25)

# %%
plt.figure(figsize=(20,5))
plt.plot(x,y)
plt.plot(x2,y+2)
#plt.plot(x3,y)
plt.show()

# %%
x[-1]*1e-6
# Out:
# 0.053267999999999996

# %%
x2[-1]*1e-6
# Out:
# 0.043004

# %%
sum(a*1e-6)
# Out:
# 0.04302799999999998

# %%
plt.plot(a)
plt.plot(b)
plt.show()

# %%
plt.hist(a[a<2000])
# Out:
# (array([12., 12.,  0.,  0.,  0.,  0.,  0.,  0., 11., 13.]),
#  array([ 460.,  518.,  576.,  634.,  692.,  750.,  808.,  866.,  924.,
#          982., 1040.]),
#  <a list of 10 Patch objects>)

# %%
a[a<700]=0
a[a>700]=1
a[0]=2

# %%
plt.plot(np.repeat(a,2))
plt.show()

# %%
a[0]
# Out:
# 2

# %%
print(a)
# Out:
# [6996 1040  460 1036  468  532  968  536  968  532  968 1032  472  528
#   972 1028  468 1028  472 1028  476 1024  480 1020  484  516  980  524
#   980  520  980  520  984  516  984  520  976 1024  476  524  980  520
#   976  528  972 1024  480  524  984]

# %%
a=[13139874,12972066,12805138,13192082,13139874,12972066,12805138,13192082,13139874,12972066,12805138,13192082,13139874,12972066,12805138,13192082,13139874,12972066,12805138,13192082,13139874]
a=np.array(a)
#2 v

# %%
print(a)
# Out:
# [13139874 12972066 12805138 13192082 13139874 12972066 12805138 13192082
#  13139874 12972066 12805138 13192082 13139874 12972066 12805138 13192082
#  13139874 12972066 12805138 13192082 13139874]

# %%
set(a)
# Out:
# {12805138, 12972066, 13139874, 13192082}

# %%
a[a==13139874]
# Out:
# array([13139874, 13139874, 13139874, 13139874, 13139874, 13139874])

# %%
plt.plot(a)
plt.plot([0,20],[13139874,13139874])
plt.scatter([8,12,16],[13139874,13139874,13139874])
plt.show()

# %%
D on 
1100 1000011111111010 0010
1100 0101111100000010 0010
1100 0011011001000001 0010
1100 1001010010111001 0010
                    1 0 2 secuencia larga
 
cuando van juntas acaban en 00100
1 2 2 2 ? en cadena pausa y 2 tres veces cadena empieza en 2

tres cortas de 3 y larga de 3 4 4 4 corta de 4

raro que reciva señal sin emitir radio.

resumen

1 1 1 1222 2 2 2 2? 3 3 3 3444 4?
1 1 1 1222 2 2 2 2333 3 3 3 3444 4111

D off
2255 2555 22..

1100 1110110100100111 0010
1100 1111000100011011 0010
1100 0010110010100011 0010
1100 0000100101010100 0010

# %%
a=[2532,560,428,2060,52,832,120,116,3856,1028,1636,1428,940,244,108,2940,776,3692,8152,1420,728,448,1356,3644,5464,204,2140,288,820,868,340,180,3420,248,692,2324,3160,492,1772,568,604,1100,612,2812,2144,3420,648,400,5400,768,2984,296,608,544,1200,452,792,224,140,3880,1908,176,2548,360,2916,60,1112,84,968,276,2128,2000,544,288,536,904,5572,244,1500,804,432,524,444,380,676,600,1144,2864,6232,220,88,332,1852,1004,1600,3664,116,1916,124,144,6872,860,88,624,1348,2608,80,184,688,3048,2916,156,856,92,2584,1820,4792,3112,1096,536,6724,1636,2108,908,544,3304,7576,2832,2784,1428,112,960,276,1316,3444,612,4040,756,784,264,1896,640,152,2516,780,448,124,380,1524,176,1392,1376,680,260,2300,612,2852,112,1216,2524,160,2676,3016,1276,2728,316,3600,160,676,2160,552,548,1536,1368,2364,268,2360,516,1628,716,1560,6744,1964,392,1984,1340,1936,180,1444,972,260,3548,816,2236,732,1008,5800,1468,164,1832,576,412,884,296,1664,164,6460,404,2368,768,1060,424,856,2032,2388,856,3928,104,160,196,1428,1036,172,2196,768,4568,5740,1068,832,2180,4456,136,320,476,188,476,2176,1016,124,116,3088,1900,324,3504,1004,852,144,1596,2452,252,5580,828,2436,212,1080,1256,128,2360,3936,632,2800,124,3336,504,912,2076,408,1764,212,2804,1144,780,476,920,3616,1660,1524,1708,484,376,240,1084,2960,1404,7024,940,1536,104,932,3192,692,724,572,292,8164,616,1764,904,268,1920,656,368,1828,388,4584,172,1292,760,144,768,572,604,296,2004,100,2268,3072,152,1492,432,2656,364,2384,5648,308,976,324,696,548,700,5744,704,2188,976,616,1176,104,936,1780,80,8088,1536,800,188,3292,892,2588,752,3904,1084,68,3692,3008,256,192,1980,1468,1936,1180,144,332,1512,2192,2020,2812,2348,2060,808,6468,588,272,1000,2892,2772,2116,548,692,384,3384,568,224,1272,364,1608,1468,156,452,5452,124,104,372,936,1444,880,6928,1528,512,1672,672,1048,8416,1408,2548,4904,6464,340,3316,392,1280,280,200,824,288,764,392,444,508,508,5380,436,1336,1676,1948,776,1516,708,240,2616,128,384,8632,508,940,668,1080,2008,436,988,8852,232,6400,324,1980,536,3552,320,2428,1700,740,596,2472,2312,468,532,8916,1288,2252,540,76,2908,3760,156,1212,292,964,620,6432,232,920,500,100,1860,84,1556,1744,764,3936,64,4328,3440,352,1520,5704,264,72,456,236,1236,76,404,896,1944,1668,1164,116,820,76,396,80,556]

# %%
plt.hist(a)
# Out:
# (array([256.,  93.,  64.,  37.,  16.,   4.,  12.,  10.,   1.,   7.]),
#  array([  52. ,  938.4, 1824.8, 2711.2, 3597.6, 4484. , 5370.4, 6256.8,
#         7143.2, 8029.6, 8916. ]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(a)
plt.xlim([300,500])
# Out:
# (300.0, 500.0)

# %%
B on

    
1100 0010110010100011 0100
1100 1111000100011011 0100
1100 1110110100100111 0100
1100 0000100101010100 0100

B off

1100 0011011001000001 0100
1100 0101111100000010 0100
1100 1000011111111010 0100
1100 1001010010111001 0100

# %%
tienes 4 sin sinc bit o muy pequeño y entre ellos un delay de algunos ms

# %%
7000*1e-6
# Out:
# 0.006999999999999999

# %%
print(int('0010110010100011', 2))
print(int('1111000100011011', 2))
print(int('1110110100100111', 2))
print(int('0000100101010100', 2))
# Out:
# 11427
# 61723
# 60711
# 2388

# %%
print(int('0011011001000001', 2))
print(int('0101111100000010', 2))
print(int('1000011111111010', 2))
print(int('1001010010111001', 2))
# Out:
# 13889
# 24322
# 34810
# 38073

# %%
general 
<init>  <on>  <remote>
1100            0000 A
                0100 B
                1100 C
                0010 D
                1010 Master
